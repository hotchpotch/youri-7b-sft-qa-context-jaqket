# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "rinna/youri-7b-instruction"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    # use_safetensors=True,
    use_flash_attention_2=True,
    # use_triton=True,
).half()
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# You are attempting to use Flash Attention 2.0 without specifying a torch dtype. This might lead to unexpected behaviour

# %%
import torch


def get_cuda_current_memory_allocated():
    return int(torch.cuda.memory_allocated() / 1024 / 1024)


print("load model cuda memory(MB):", get_cuda_current_memory_allocated())
# Out:
# load model cuda memory(MB): 11122

# %%
RESPONSE_MESSAGE = "応答"
RESPONSE_PROMPT = f"### {RESPONSE_MESSAGE}: \n"
DEVICE = "cuda:0"


def build_prompt(
    user_message: str,
    inputs: str | None = "",
    separator: str = "\n\n### ",
    response_message: str = RESPONSE_MESSAGE,
) -> str:
    system_message = "以下は、タスクを説明する指示と、文脈のある入力の組み合わせです。要求を適切に満たす応答を書きなさい。"
    prompt = system_message
    roles = ["指示", response_message]
    messages = [": \n" + user_message, ": \n"]

    if inputs:
        roles = ["指示", "入力", response_message]
        messages = [": \n" + user_message, ": \n" + inputs, ": \n"]

    for role, message in zip(roles, messages):
        prompt += separator + role + message
    return prompt


def qa(model, tokenizer, question, context, build_prompt_fn=build_prompt):
    prompt = build_prompt_fn(question, context)
    token_ids = tokenizer.encode(prompt, add_special_tokens=False, return_tensors="pt")

    with torch.no_grad():
        output_ids = model.generate(
            input_ids=token_ids.to(DEVICE),  # type: ignore
            max_new_tokens=24,
            do_sample=False,
            # temperature=0.0,
            pad_token_id=tokenizer.pad_token_id,
            bos_token_id=tokenizer.bos_token_id,
            eos_token_id=tokenizer.eos_token_id,
        )
    output = tokenizer.decode(output_ids.tolist()[0])
    # prompt を取り除く
    output = output.replace(prompt, "")
    # eos_token 以降を取り除く
    output = output.split(tokenizer.eos_token)[0]
    return output.strip()

# %%
question = "楽曲『約束はいらない』でデビューした、声優は誰？"
context = """
(0.21018645, '約束はいらない', '「約束はいらない」(やくそくはいらない)は、坂本真綾のデビューシングル。') (0.24241784, '約束はいらない', '坂本真綾の歌手デビュー作品。当時坂本はまだ無名の声優であったが、同曲がテーマソングとなったアニメ『天空のエスカフローネ』とともに知名度を上げることとなる。後に「指輪」が同アニメの劇場版映画の主題歌とな') (0.2441598, '坂本真綾', '本格的な歌手活動は、1996年にテレビアニメ『天空のエスカフローネ』へ出演したことがきっかけで始めており、同作のオープニングテーマソングである「約束はいらない」(岩里祐穂作詞、菅野よう子作曲)をシング') (0.26043588, 'Suara', '大阪府立豊中高等学校を経て大阪外国語大学でインドネシア語を専攻中にバンド・ユニットを組んで音楽活動を始めた。普段はお笑い番組が大好きなこともあってよく喋るほうだが、東京の仕事で標準語の喋りをする時は、') (0.2690969, '早見沙織', '声優デビュー時より、数多くの主題歌やキャラクターソングを担当し、バラードからポップス、ヒットソングのカバー曲や英語の楽曲など、様々な曲を歌いこなす。2009年には吉田仁美とのユニット「blue dro')
"""

print(qa(model, tokenizer, question, context))
# Out:
# 坂本真綾

# %%
import pandas as pd
import datasets

ds = datasets.load_dataset("hotchpotch/jaqket_v1_qa_wikija_context")  # type: ignore
valid_ds = ds["validation"]  # type: ignore
valid_df = valid_ds.data.to_pandas()  # type: ignore
# context は list なので、 "\n" で結合する
valid_df["context"] = valid_df["context"].apply(lambda x: "\n".join(x) + "\n")
valid_df.head(1)
# Out:
# Downloading readme:   0%|          | 0.00/2.78k [00:00<?, ?B/s]
# Downloading and preparing dataset None/None to /home/yu1/.cache/huggingface/datasets/hotchpotch___parquet/hotchpotch--jaqket_v1_qa_wikija_context-5a22350c2a63a9e4/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/4.70M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.58M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/2939 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/980 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /home/yu1/.cache/huggingface/datasets/hotchpotch___parquet/hotchpotch--jaqket_v1_qa_wikija_context-5a22350c2a63a9e4/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
#              qid                                           question  \
# 0  QA20QBIK-0912  手術によって天才となったチャーリイ・ゴードンの日記という形式を通して語られる、ダニエル・キイ...
#
#         answer                                            context  \
# 0  アルジャーノンに花束を  ダニエル・キイス 「アルジャーノンに花束を」は中編もそれを発展させた長編も、知的障害者のチャ...
#
#          answers competition   timestamp         section number  \
# 0  [アルジャーノンに花束を]      第1回AI王  2020/01/27  開発データ問題 (dev1)    912
#
#                                    original_question original_answer  \
# 0  手術によって天才となったチャーリイ・ゴードンの日記という形式を通して語られる、ダニエル・キイ...     アルジャーノンに花束を
#
#   original_additional_info
# 0

# %%
# valid_df での正解率を測る
from tqdm import tqdm

# valid_df = valid_df.head(10)

valid_df = valid_df.reset_index(drop=True)
for i in tqdm(range(len(valid_df))):
    pred_text = qa(
        model, tokenizer, valid_df.loc[i, "question"], valid_df.loc[i, "context"]
    )
    valid_df.loc[i, "pred"] = pred_text
# Out:
# 100%|██████████| 980/980 [1:10:18<00:00,  4.31s/it]

# %%
# 完全一致の正解率を表示
valid_df["is_correct"] = valid_df["answer"] == valid_df["pred"]
valid_df["is_correct"].mean()
# Out:
# 0.5908163265306122

# %%
# 間違ったものだけを表示
incorrect_df = valid_df[["question", "answer", "pred", "is_correct"]][
    valid_df["is_correct"] == False
]

# %%
# 部分一致の正解率を表示
valid_df["is_correct"] = valid_df.apply(lambda x: x["answer"] in x["pred"], axis=1)
valid_df["is_correct"].mean()
# Out:
# 0.7326530612244898

# %%
# 間違ったものだけを表示
valid_df[["question", "answer", "pred", "is_correct"]][valid_df["is_correct"] == False]
# Out:
#                                               question      answer  \
# 1    1890年に日本初の電動エレベーターが設置された、かつて東京・浅草にあったが、関東大震災で半...         凌雲閣
# 3         現代の「世界三大ギタリスト」と称されるのはデレク・トラックス、ジョン・フルシアンテと誰?    ジョン・メイヤー
# 4    テレビ番組の検証映像でもよく使用される、映した物体の温度を色分けして表示する装置を何というで...    サーモグラフィー
# 5      不景気にもかかわらず、原材料の高騰などで物価水準が上昇し続ける状態のことを経済用語で何という?   スタグフレーション
# 7    古代ギリシャの彫刻が起源とされ、飛鳥時代の仏像にも見られる、口元に微笑みを浮かべたように見え...  アルカイク・スマイル
# ..                                                 ...         ...
# 964  旅客機の座席で、ファーストクラスとエコノミークラスの中間にあたるものを一般に何クラスというで...     ビジネスクラス
# 966  2020年シーズン、読売ジャイアンツの丸佳浩が試合での登場時に主に流していたのは、何という歌...        LiSA
# 967                2人で行う花札の遊び方で、「五光」や「猪鹿蝶」といった役があるのは何?        こいこい
# 978                           掛け算で使う「×」の記号のもとになったものは何?         十字架
# 979   細長く切ったイカの刺し身を、醤油やつけ汁につけて食べる料理のことを、ある麺類にたとえて何という?      イカそうめん
#
#                         pred  is_correct
# 1                      浅草十二階       False
# 3    デレク・トラックス、ジョン・フルシアンテ、ジョ       False
# 4                       色温度計       False
# 5                        デフレ       False
# 7                アルカイック・スマイル       False
# ..                       ...         ...
# 964                 エコノミークラス       False
# 966      2020年シーズン、読売ジャイアンツの       False
# 967      花札の遊び方で、2人で行うものとしては       False
# 978        掛け算の「掛ける」を意味する英語の       False
# 979          イカの刺し身を、醤油やつけ汁に       False
#
# [262 rows x 4 columns]

# %%
print(
    valid_df[["question", "answer", "pred", "is_correct"]][
        valid_df["is_correct"] == False
    ].to_csv()
)
# Out:
# ,question,answer,pred,is_correct
# 1,1890年に日本初の電動エレベーターが設置された、かつて東京・浅草にあったが、関東大震災で半壊し、撤去された高層建築物は何?,凌雲閣,浅草十二階,False
# 3,現代の「世界三大ギタリスト」と称されるのはデレク・トラックス、ジョン・フルシアンテと誰?,ジョン・メイヤー,デレク・トラックス、ジョン・フルシアンテ、ジョ,False
# 4,テレビ番組の検証映像でもよく使用される、映した物体の温度を色分けして表示する装置を何というでしょう?,サーモグラフィー,色温度計,False
# 5,不景気にもかかわらず、原材料の高騰などで物価水準が上昇し続ける状態のことを経済用語で何という?,スタグフレーション,デフレ,False
# 7,古代ギリシャの彫刻が起源とされ、飛鳥時代の仏像にも見られる、口元に微笑みを浮かべたように見える表情を何というでしょう?,アルカイク・スマイル,アルカイック・スマイル,False
# 8,ラテン語では「アーリア・ヤクタ・エスト」という、カエサルがルビコン川を渡る際に言ったとされる有名な言葉は何でしょう?,賽は投げられた,アーレア・ヤクタ・エスト,False
# 10,本場鹿児島では「つけあげ」と呼ばれる揚げ物は何でしょう?,薩摩揚げ,鹿児島では、エソを使った「つけあげ」が,False
# 12,ラベンダー、ローズマリー、バジル、ミントといえば何科の植物?,シソ科,ラベンダー、ローズマリー、バジル、ミントはシソ,False
# 13,世界最大のヒゲクジラはシロナガスクジラですが、世界に広く分布している世界最大のハクジラは何?,マッコウクジラ,世界最大のハクジラはシロナガスクジラですが、世,False
# 14,飛行機の操縦士としての体験を元に小説『夜間飛行』や童話『星の王子様』などの作品を残したフランスの作家は誰でしょう?,アントワーヌ・ド・サン=テグジュペリ,アントワーヌ・ド・サン＝テグジュペリ,False
# 16,白ワイン「シャブリ」の原料でもある、フランス・ブルゴーニュ地方の村の名前がついたブドウの品種は何?,シャルドネ,シャブリは、フランス・ブルゴーニュ地方の村の名,False
# 18,端午の節句には鯉のぼりと一緒にあげる、ひらひらとたなびく筒状の布を何というでしょう?,吹流し,鯉のぼり,False
# 20,レールをまたぐ方式と、レールにつり下がる方式がある、1本のレールに沿って走る鉄道を何という?,モノレール,鉄道は、レールをまたぐ方式と、レールにつり下が,False
# 21,ドイツの医師クルムスの『ターヘル・アナトミア』を翻訳したものである、江戸時代に杉田玄白らが著した医学書は何でしょう?,解体新書,ターヘル・アナトミアは、杉田玄白、,False
# 28,鎌倉幕府や室町幕府が荘園を管理支配するために設置した役職で、道理の通じない相手の例えとして「泣く子とコレには勝てぬ」ともいわれるのは何でしょう?,地頭,小侍所,False
# 31,阪急やオリックスで活躍した星野伸之の現役時代のニックネームであった、サン=テグジュペリの代表作である小説は何でしょう?,星の王子さま,星野伸之の現役時代のニックネームは「星,False
# 32,ミンタカ、ベラトリックス、リゲル、ベテルギウスといえば、何という星座を構成する星でしょう?,オリオン座,ミンタカ、ベラトリックス、リゲル、ベテルギウス,False
# 35,クラブなどで人々を踊らせるための電子音楽のことを「EDM」といいますが、これは何という言葉の略でしょう?,エレクトロニック・ダンス・ミュージック,EDMは、Electronic Dance Musicの略です。,False
# 53,化粧品メーカー「資生堂」の名前の由来となった一節が登場する、中国の四書五経のひとつは何?,易経,資生堂の名前の由来は、中国の古典『����,False
# 63,パーツ、グラビア、読者、ファッションの後ろに共通してつく言葉は何?,モデル,パーツ、グラビア、読者、ファッションの後ろ,False
# 67,雑誌などで発表せず、直接単行本などで出版される小説のことを何というでしょう?,書き下ろし,単行本,False
# 72,兵庫県の「岩津」、埼玉県の「深谷」、群馬県の「下仁田」といえばどんな野菜のブランドでしょう?,ネギ,岩津ねぎは兵庫県朝来市岩津で�����,False
# 74,アイヌの伝承では柳の葉が人間の世界に流れ出て魚になったという、北海道南部に分布するキュウリウオ科の魚は何?,シシャモ,キュウリウオ,False
# 83,ティーンエイジャー向けに書かれた小説のことで、英語で「少年向け」という意味があるジャンルを何小説という?,ジュブナイル,ライトノベル,False
# 86,マニュアル自動車についている3つのペダルとは、アクセルペダル、ブレーキペダルと何でしょう?,クラッチペダル,マニュアル車の3つのペダルは、アクセルペダル、,False
# 91,正式なタイトルは『凱風快晴』という、葛飾北斎の『富嶽三十六景』の中の1枚の色を使った通称は何?,赤富士,凱風快晴」は、葛飾北斎,False
# 93,例年9月にある国民の祝日といえば、敬老の日と何でしょう?,秋分の日,敬老の日,False
# 96,ユニバーサルやパラマウントといった多くの映画会社の撮影所があることから、「映画の都」と呼ばれる、アメリカ・カリフォルニア州の街はどこ?,ハリウッド,カリフォルニア州ロサンゼルスのユニバーサル・シ,False
# 99,アフリカの国・シエラレオネの国旗と同じ色の並びの看板を使っている、日本のコンビニチェーンは何?,ファミリーマート,セブン-イレブン,False
# 103,もとは液体だった、乳酸菌やポリフェノールを含む機能性食品としても人気の、カカオを原料とした甘い食べ物といえば何?,チョコレート,カカオ,False
# 107,朝鮮語で「桔梗の花」という意味の、『アリラン』とともに朝鮮半島で愛唱される民謡は何?,トラジ,アリラン,False
# 111,小麦粉を水で溶いた生地で熱した鉄板に文字を書いて遊んだことがきっかけで作られた、かつては「文字焼き」とよばれていた料理は何でしょう?,もんじゃ焼き,どんどん焼き,False
# 113,ガーナのカカオや、キューバの砂糖などのように、一国の経済がある特定の作物の生産・輸出に依存している経済を何という?,モノカルチャー,特定の作物の生産・輸出に依存した�,False
# 118,リトマス試験紙とBTB溶液に共通する、アルカリ性を示す色は何でしょう?,青,リトマス試験紙とBTB溶液に,False
# 122,劇中歌『ショウほど素敵な商売はない』も知られている、実在した射撃の名手の女性を描いたミュージカルは何?,アニーよ銃をとれ,アニー・オークレイ,False
# 125,事前に整理券を受け取ることで並ばずに参加できる、東京ディズニーリゾートで一部のアトラクションに導入されているシステムは何でしょう?,ディズニー・ファストパス,東京ディズニーリゾートでは、東京ディズニー,False
# 128,1954年に短編小説『驟雨』で芥川賞を受賞した、安岡章太郎、遠藤周作らとともに「第三の新人」と呼ばれた作家は誰?,吉行淳之介,山本周五郎,False
# 129,サッカーで、ファールを受けたように見せかけて倒れる反則を何というでしょう?,シミュレーション,ダイビング,False
# 130,『ビタースイートサンバ』という曲がテーマソングとして使われている、ニッポン放送の長寿深夜ラジオ番組は何?,オールナイトニッポン,ビタースイートサンバ』は、ニッポン放送の長��,False
# 134,日本の国土を大きく二つに分類すると、本州など5つの島による本土と、それ以外の何でしょう?,離島,日本の国土を大きく二つに分類すると、本州な,False
# 142,アンデルセンの『人魚姫』で、人魚姫が足をもらうために失ったものは何でしょう?,声,人魚姫は、足をもらうために、尻尾を,False
# 145,3、4人で1人を担ぎ、上の人が帽子や鉢巻などを奪いあう、よく運動会で行われる競技は何でしょう?,騎馬戦,棒倒し、川中島、順送球,False
# 151,ドイツでは無免許でこれを行うと罰金が科せられる、古くから川や海で行われてきた英語では「fishing」という娯楽といえば何でしょう?,釣り,フィッシング,False
# 153,アメリカの映画やドラマなどにもよく登場する、高校生たちが卒業記念に開くダンスパーティを何という?,プロム,アメリカやカナダの高校で学年末に開かれるフ,False
# 154,白色のエムデン種、茶褐色のツルーズ種が代表的な品種である、野生のガンを飼いならした鳥は何?,ガチョウ,カナダガン,False
# 157,日本の浴衣をヒントに考案されたとされている、トロピカルなモチーフが描かれた、ハワイの定番シャツといえば何でしょう?,アロハシャツ,かりゆしウェア,False
# 160,1956年までは「べドロー島」という名前だった、自由の女神像があるニューヨーク湾の小島は何でしょう?,リバティ島,1956年までは「ベドロー島」と呼ばれてい,False
# 169,オリンピックで金メダルを獲得した荒川静香、羽生結弦といえば、どんな競技の選手でしょう?,フィギュアスケート,荒川静香、羽生結弦はフィギュア,False
# 172,地球の大気中に最も多く含まれている気体は何でしょう?,窒素,地球の大気中に最も多く含まれている気体は�,False
# 178,2019年1月に現役を引退した横綱・稀勢の里が襲名した年寄名跡は何でしょう?,荒磯,二所ノ関部屋,False
# 183,紐の巻き方によって、男巻き、女巻き、十字巻きなどに大別される、大正から昭和にかけて子供に大流行した喧嘩独楽の一種は何でしょう?,ベーゴマ,糸巻きゴマ,False
# 189,セム、ハム、ヤペテの3人の息子とその妻たちと共に方舟に乗り、大洪水を生き延びた、聖書に登場する人物は誰でしょう?,ノア,セム、ハム、ヤペテ,False
# 193,中南米の国々の食文化において、アボカドを潰したペーストの「ワカモレ」、様々な具を挟んで作る「タコス」は、どこ料理として有名でしょう?,メキシコ料理,中南米の国々では、アボカドを潰したペースト,False
# 198,伊坂幸太郎の小説『ゴールデンスランバー』でも扱われている、無実にも関わらず犯罪者とされてしまうことを何という?,冤罪,無実の罪,False
# 203,上方置換と下方置換のうち、塩化水素のような水に溶けやすく、空気より重い気体を集めるときに使う手法はどっち?,下方置換,上方置換,False
# 204,レストランで、ワインを専門分野とする給仕を何というでしょう?,ソムリエ,テーブルワインとは、食事と共に楽しむワインのこ,False
# 207,北海道の都市で、札幌市に次いで人口が多いのはどこでしょう?,旭川市,北海道の都市で、札幌市に次いで人口が多,False
# 208,「煮込んだ生クリーム」という意味がある、生クリーム・牛乳・砂糖を合わせて煮詰め、ゼラチンで固めたイタリアのデザートは何?,パンナ・コッタ,パンナコッタ,False
# 211,一般に労働三法と呼ばれる法律は、労働基準法、労働組合法と何でしょう?,労働関係調整法,労働基準法、労働組合法,False
# 218,ギリシャ語の「巨人」を語源とする、「メガ」よりも千倍大きい「十億倍」を意味する言葉は何でしょう?,ギガ,"メガ メガ(mega, 記号:M)は国際単",False
# 226,かまぼこや焼き魚にして食べられる、主に北海道で捕れるアイナメ科の魚で、漢字では魚へんに花と書くのは何でしょう?,ホッケ,アイナメ,False
# 227,スコットランドの民謡『オールド・ラング・サイン』を原曲とする、卒業式やお店の閉店BGMの定番曲といえば何でしょう?,蛍の光,オールド・ラング・サイン,False
# 228,2012年には吉高由里子と生田斗真主演で映画化されている、高橋七美と矢野元晴の恋愛を描いた、小畑友紀の漫画は何?,僕等がいた,スミレはブルー,False
# 230,家庭用の「コンシューマーゲーム」に対し、ゲームセンターなどで遊ぶための業務用ゲームを何ゲームというでしょう?,アーケードゲーム,業務用ゲーム機,False
# 234,島の3分の1を米軍基地が占めている、恋人岬などの名所で有名な、日本人に人気のリゾート島は何でしょう?,グアム,テニアン島,False
# 236,トム・クルーズとニコール・キッドマンが共演した、スタンリー・キューブリック監督の遺作としても知られる1999年の映画は何?,アイズ ワイド シャット,デイズ・オブ・サンダー,False
# 243,一般的には融点と同じ値をとる、物質が液体から個体に変化する温度を何というでしょう?,凝固点,融解,False
# 246,生物学でRNAからたんぱく質を合成することと、ある言語の文章を他の言語に変換することに共通する言葉は何でしょう?,翻訳,生物学でRNAからタンパク質を合成することと,False
# 249,モロッコでは約3割、アルジェリアでは約2割の住民が該当するという、アフリカのマグレブ地方の先住民族を何人という?,ベルベル人,モロッコでは約3割、アルジェリアでは�,False
# 253,農民などが無礼を働いた場合に斬りつけても処罰をうけないという、江戸時代の武士の特権のことを何というでしょう?,切捨御免,無礼討ち,False
# 255,美人のこれは「富士」にたとえられ、せまい場所は「猫」のものにたとえられる顔の部分は何でしょう?,額,美人のこれは「富士」にたとえられ、せまい場所は,False
# 256,監督はビリー・ワイルダー、主演をジャック・レモンとシャーリー・マクレーンが務め、アカデミー作品賞を受賞した作品は何?,アパートの鍵貸します,恋人よ帰れ!わが胸に』は、ビリー・ワイ,False
# 258,寿司屋の用語で「がり」といえばショウガのことですが、「あがり」といえば何でしょう?,茶,アガリとは、寿司屋の符牒で、�����,False
# 262,父が山口県と山形県の長官を務めていたことから「山」という漢字を2つ重ねた名前がつけられた、『広辞苑』の編纂を手掛けた言語学者は誰?,新村出,阪倉篤義,False
# 267,中国周代の道学者・関尹子の著書のなかに記されている、三者が互いに牽制しあって身動きが取れない状態を、ヘビ、カエル、ナメクジに例えて何という?,三すくみ,ヘビ、カエル、ナメクジの三者が互いに得,False
# 268,「アラビアガム」という添加物にちなんだ、アイスコーヒーなどに入れる甘いシロップは何?,ガムシロップ,アラビアガム,False
# 269,2017年12月から2018年6月まで国際宇宙ステーションでの滞在ミッションを行っていた、防衛医科大学校出身の日本人宇宙飛行士は誰でしょう?,金井宣茂,油井亀美也,False
# 270,「LED」の「L」は「ライト」、「E」は「エミッティング」の頭文字ですが、「D」は何という言葉の頭文字?,ダイオード,ドリーム,False
# 275,林子平が『三国通覧図説』を刊行した時の日本の元号は何でしょう?,天明,天平,False
# 278,カンヌ国際映画祭の賞の名前。最高賞は「パルム・ドール」ですが、新人監督に与えられる賞は何?,カメラ・ドール,カンヌ国際映画祭の新人����,False
# 280,経済産業省が持つ3つの外局とは、資源エネルギー庁、特許庁と何?,中小企業庁,経済産業省には、資源エネルギー,False
# 282,「しおりひも」ともいう、本や手帳の綴 じ目の上部にのり付けされていることがある紐を何という?,スピン,しおりひも,False
# 287,「ハワイ」を英語で書いたとき、2回出てくる文字は「A」と何?,I,ハワイ語のアルファベットでは、'（アポストロフ,False
# 295,大相撲で、三賞と呼ばれる3つの賞とは、技能賞、殊勲賞と何賞?,敢闘賞,技能賞、殊勲賞、�������,False
# 297,各省や国務大臣を長とする庁に置かれる、大臣に次ぐ官僚トップの役職を何という?,事務次官,局長,False
# 305,メンバー2人の下の名前はどちらも「のぶゆき」である、「ヤホーで調べました」などのネタでおなじみのお笑いコンビといえば何でしょう?,ナイツ,どぶろっく,False
# 308,『パリのアメリカ人』『ラプソディ・イン・ブルー』などの作品で知られるアメリカの作曲家は誰でしょう?,ジョージ・ガーシュウィン,ジョージ・ガーシュイン,False
# 312,カンパリにグレープフルーツジュースとトニックウォーターを混ぜて作られる、イタリア語で「泡立つ」という意味のカクテルは何?,スプモーニ,カンパリ・グレープフルーツ,False
# 315,古い言葉では「みずかね」とも呼ばれた、常温で液体の形をとる金属は何でしょう?,水銀,液体金属は、融点から沸点の間で��,False
# 322,日本ではスギ、ヒノキに次いで花粉症の患者数が多く、秋に花粉症を引き起こすことで知られる北米原産のキク科の植物は何でしょう?,ブタクサ,キク,False
# 324,縁起の良いものとして男の子につけられた、とてつもなく長い名前を主題とする有名な古典落語は何でしょう?,寿限無,長い名の子,False
# 325,12インチを1とする、ヤートポンド法の単位は何でしょう?,フィート,12インチは1ヤードポンド法の単位です。,False
# 327,『ねじまき島の冒険』『麦わらチェイス』といった劇場版作品が公開されている、フジテレビ系列の人気アニメは何?,ONE PIECE,ワンピース,False
# 332,マレーシア航空の旅客機の尾翼に描かれている、お正月でおなじみのおもちゃは何?,凧,マレーシア航空の垂直尾翼には、伝統,False
# 334,「賤ヶ岳の七本槍」の一人でもあり、熊本城を築城するなど、築城の名手としても知られた、戦国時代の武将は誰?,加藤清正,福島正則,False
# 335,印鑑を押す際に用いる、スポンジなどに赤い顔料を染み込ませたものを何というでしょう?,朱肉,シヤチハタ,False
# 341,和名を「ハナハッカ」という、イタリア料理にしばしば用いられるシソ科の多年草は何?,オレガノ,ハナハッカ,False
# 351,アフリカの国・ボツワナ共和国の面積のおよそ7割を占める、アフリカ大陸南部に広がる砂漠は何?,カラハリ砂漠,ボツワナの国土の約7割を占める��,False
# 352,首都圏に含まれるが、関東地方には含まれない唯一の都道府県はどこでしょう?,山梨県,首都圏に含まれるが、関東地方には含,False
# 356,1618年のベーメンの反乱から始まり1648年のウェストファリア条約の締結で終結した一連の戦争のことを、その年数から一般に何戦争というでしょう?,三十年戦争,八十年戦争,False
# 358,1785年、イギリスでカートライトが発明し、産業革命の誘因となった、蒸気機関によって動く織機を何という?,力織機,ジェニー紡績機,False
# 359,2019年2月16日に藤井聡太が優勝し二連覇を達成した、朝日新聞社が主催する将棋の棋戦は何でしょう?,朝日杯将棋オープン戦,朝日杯将棋オープン,False
# 369,北京の天安門正面に掲げられた肖像画でも有名な、中国共産党を組織し中華人民共和国を建国した、同国の最高指導者は誰でしょう?,毛沢東,中国共産党の最高指導者は、中華人民,False
# 375,紅白歌合戦にもゲスト出演した2人組「ず〜まだんけ」といえば、どんなおもちゃを使ったパフォーマーでしょう?,けん玉,ず〜まだんけ,False
# 376,1月7日に邪気を払うために食べられる、セリやナズナなどの七草を入れて作られる料理は何?,七草がゆ,七草粥,False
# 379,地質時代の区分で、陸上では裸子植物や恐竜など、海中ではアンモナイトなどが栄えた、白亜紀・ジュラ紀・三畳紀のことをまとめて何代という?,中生代,白亜紀・ジュラ紀・三畳紀,False
# 380,実写映画『テルマエ・ロマエ』で、主人公のローマ人・ルシウスを演じた俳優は誰でしょう?,阿部寛,実写映画『テルマエ・ロマエ』で、主人公のロ,False
# 381,大阪の天満天神繁昌亭や東京の新宿末廣亭など、落語や講談などを興行する大衆的な演芸場を何という?,寄席,天満天神繁昌亭や新宿�������,False
# 382,春は京都競馬場、秋は東京競馬場で開催される競馬のG1レースは何でしょう?,天皇賞,春は東京競馬場、秋は京都競馬場で開��,False
# 388,キャッスル・マウンテンやレイク・ルイーズなどの見どころがある、1887年に設立されたカナダ初の国立公園は何でしょう?,バンフ国立公園,カナダ国立公園,False
# 393,数学で、小文字では標準偏差を、大文字では合計を表すギリシャ文字は何でしょう?,Σ,数学では、小文字のgreek alphabetは����������,False
# 394,別名を「マーカス島」という、東京都小笠原村に属する日本最東端の島は何でしょう?,南鳥島,マーカス島は、別名をマルカス島といい、東京都小,False
# 396,デンマーク語で「15」という意味を持つ、10のマイナス15乗を表すSI接頭語は何?,フェムト,デンマーク語で「15」という意味を持つ接頭,False
# 397,日本語では「たんぱく石」と呼ばれる、10月の誕生石は何でしょう?,オパール,トルマリン,False
# 399,ロシアの科学者が教育用ソフトとして開発した、4つの正方形を組み合わせた7種類のブロックピースを積み、横一列をそろえて消す、というゲームは何?,テトリス,ブロックス,False
# 403,野球のポジションで「C」と表記されるのはどこでしょう?,捕手,野球のポジションで「C」と表記されるのは捕,False
# 404,「梅田の停車場を下りるや否や自分は母からいいつけられた通り、すぐ俥を雇って岡田の家に馳けさせた。」という書き出しで始まる、『彼岸過迄』『こゝろ』とともに夏目漱石の後期三部作をなしている小説は何でしょう?,行人,彼岸過迄,False
# 409,学名を「クラミドサウルス・キンギイ」という、首元の皮膚を広げて威嚇する姿から名前が付けられたトカゲは何でしょう?,エリマキトカゲ,クラミドサウルス・キンギイ,False
# 417,フランスパンに、肉・野菜の酢漬け・香草など、さまざまな具材を挟んだベトナムのサンドイッチを何という?,バインミー,フランスパンに、肉・野菜の酢漬け・,False
# 418,「シンガポール・フライヤー」や「ロンドン・アイ」といえば、どんな種類の観光名所でしょう?,観覧車,ロンドン・アイ」や「シンガポール・フライヤー」,False
# 419,分子式「C6H12O6」で表される、ラクトースを加水分解するとブドウ糖とともに得られる単糖類の一種は何?,ガラクトース,ラクトースを加水分解するとブドウ糖とともに,False
# 423,アニメ『はたらく細胞』で、花澤香菜演じる主人公は、身体の何という細胞が擬人化されたキャラクターでしょう?,赤血球,花澤香菜演じる主人公は、身体の白血,False
# 429,アインシュタインはこれを理由に兵役を免除されている、土踏まずがなく足の裏が地面にべったりと付く足を何というでしょう?,扁平足,アインシュタインはこれを理由に兵役を免,False
# 431,透き通るようなしょう油スープと青竹を使って打つ平麺が特徴の栃木県のご当地ラーメンは何?,佐野ラーメン,豆腐ラーメンは、豆腐とひき��,False
# 433,別名をバルバドスチェリーという、ビタミンCを多量に含むことで知られる果物は何でしょう?,アセロラ,バルバドスチェリー,False
# 435,物語のジャンルの一つ「SF」とは、何という言葉の略でしょう?,サイエンス・フィクション,SFとは、Science Fictionの略です。,False
# 438,ライフルの弾丸が通る筒の部分をイメージさせる形をしていることから、古いイタリア語で「ライフル」という意味の名前をもつ、螺旋状のショートパスタの一種は何?,フジッリ,マカロニ,False
# 441,およそ5億4000万年前に起こったとされる、アノマロカリスなど多様化した生物が一気に出現した現象のことを何というでしょう?,カンブリア爆発,カンブリア紀の生物多様化,False
# 451,ギリシャ語で「真珠」という意味の言葉に由来する、バターの代用品としてパンに塗られることが多い加工食品は何でしょう?,マーガリン,ギリシャ語で「真珠」を意味する「アンテ,False
# 453,英語では「シトリックアシッド」という、レモンやグレープフルーツなどに多く含まれる酸味成分といえば何?,クエン酸,シトリックアシッドとは、レモンやグレープフルー,False
# 454,映画において、一般公開に先立って特定の劇場のみで行われる封切り上映のことを英語で何というでしょう?,ロードショー,限定上映,False
# 455,休みの日に趣味で家具や犬小屋を作ったりすることを、ある曜日を使った表現で何というでしょう?,日曜大工,休日に趣味で家具や犬小屋を,False
# 460,和名をニクズクという、ハンバーグによく利用される香辛料は何でしょう?,ナツメグ,ニクズクは、ハンバーグによく使われる香辛料,False
# 467,人間の「五感」とは、視覚、聴覚、味覚、嗅覚とあとひとつは何でしょう?,触覚,五感とは、視覚、聴覚、��,False
# 469,和名を「タテガミイヌ」という哺乳類の生き物で、ライオンなどが食べ残した死肉を漁る習性で知られるのは何でしょう?,ハイエナ,ライオン,False
# 474,英語で家の内装を「インテリア」といいますが、外装は何という?,エクステリア,外装 建築等の用語で、建物の外部の様子,False
# 477,英語では「キャリコ・キャット」という、大半がメスの、白、黒、茶色の毛が入り混じった猫の種類は何?,三毛猫,英語では「キャリコ・キャット」という、大半,False
# 478,アメリカの社会学者ミルズが用いた用語で、国の政治・経済・軍事などの頂点にたち、国家の政策に決定権を有する者を何エリートという?,パワーエリート,国の政治・経済・軍事などの頂点にた,False
# 486,アメリカのアメリカンフットボールのプロリーグのことを、アルファベット3文字で何という?,NFL,アメリカン・フットボール・リーグ,False
# 494,ガムの包装紙や折り紙に使われる「銀紙」には、普通どんな金属箔が用いられるでしょう?,アルミ箔,銀紙には、通常、金箔が用いられます。,False
# 495,英語では「モーニング・シックネス」という、女性の妊娠中に起こる吐き気や嘔吐のことを総称して何というでしょう?,つわり,英語では「モーニング・シックネス」という、女性,False
# 499,マダガスカルがその名産地として知られるラン科の植物で、よくアイスクリームの香料に用いられているのは何でしょう?,バニラ,アングレカム・ディディエリ,False
# 503,2010年から2シーズン、メジャーリーガー・大谷翔平の兄である大谷龍太が所属した日本の野球チームは何でしょう?,高知ファイティングドッグス,大谷翔平の兄である大谷龍太は、2010,False
# 504,1970年代にヒッピーファッションとして流行した、膝下から裾へ鐘のように広がった「パンタロン」とも呼ばれるパンツのタイプを、ある楽器にたとえて何という?,ベルボトム,パンタロン,False
# 505,カナダのケベック州の公用語は、英語ではなく、何語でしょう?,フランス語,カナダのケベック州の公用語は英語ではなく、フラ,False
# 506,イグナティウス・デ・ロヨラらとともにイエズス会を設立し、1549年に日本に初めてキリスト教を伝えたスペインの宣教師は誰?,フランシスコ・ザビエル,イエズス会の創設者であるイグナティウス・デ,False
# 519,テレビアニメ『かぐや様は告らせたい〜天才たちの恋愛頭脳戦〜』のオープニングテーマ『ラブ・ドラマティック feat. 伊原六花』を歌う歌手は誰でしょう?,鈴木雅之,ラブ・ドラマティック feat. 伊原六花』を歌う歌,False
# 527,別名を「戦争犠牲者保護条約」という、戦争時の捕虜に関する事項を定めた条約を、締結された都市から何という?,ジュネーヴ条約,ジュネーヴ,False
# 531,パチンコ・パチスロで、獲得した玉やメダルを入れておく容器のことを何というでしょう?,ドル箱,パチンコ・パチスロで、獲得した玉やメダルを,False
# 537,将棋で、飛車が成ると何という名前の駒になるでしょう?,竜王,飛車が成ると飛燕になります。,False
# 538,2019年6月1日にマディソン・スクエア・ガーデンで開催された試合で、三冠王者のアンソニー・ジョシュアにTKO勝ちし、メキシコ系では初となるヘビー級王者となったボクサーは誰でしょう?,アンディ・ルイス・ジュニア,アンソニー・ジョシュア,False
# 539,野球で、タイムなどが宣告されて試合が停止している状態を、「ボールインプレイ」に対して何という?,ボールデッド,野球で、タイムなどが宣告されて試合が�,False
# 540,2019年4月から1年間、トーク番組『A-Studio』のサブMCを務めた、ドラマ『義母と娘のブルース』などに出演した女優は誰でしょう?,上白石萌歌,川栄李奈,False
# 542,原作・高森朝雄、作画・ちばてつやによるボクシング漫画で、丹下段平、力石徹、矢吹丈などのキャラクターが登場するのは何?,あしたのジョー,クロスカウンター,False
# 551,日本には1916年に川口三郎によって紹介された、脊椎のゆがみを手で矯正して健康を保とうとする治療法といえば何でしょう?,カイロプラクティック,スポンディロセラピー,False
# 562,秋田の「西馬音内盆踊り」、岐阜の「郡上おどり」と並んで日本三大盆踊りと称される、毎年夏に徳島県で行われる盆踊りといえば何でしょう?,阿波踊り,徳島市阿波おどり,False
# 564,ポルノグラフィティのシングルである『ミュージック・アワー』『サウダージ』『ハネウマライダー』が共通してCMソングに起用されたのは、何のテレビCMでしょう?,ポカリスエット,ポルノグラフィティの「ミュージック・アワー」「,False
# 566,東ローマ帝国の皇帝・ユスチニアヌス1世の命より編纂された、『法学提要』『学説彙纂』『勅法彙纂』『新勅法』などの法典の総称を何という?,ローマ法大全,ユスティニアヌス1世の命により編纂され,False
# 573,ドイツ語で「ライオンのビール」という名前の、ミュンヘンに本社を置くビールメーカーは何?,レーベンブロイ,ドイツのミュンヘンに本社を置くビールメーカ,False
# 576,臓器移植において、臓器を提供する側の人を「ドナー」といいますが、提供される側の人を何という?,レシピエント,臓器移植において、臓器を提供す,False
# 578,四書の一つに数えられる中国の書物と、日本の最高学府とされる教育機関に共通する漢字二文字の言葉は何でしょう?,大学,四書とは、孔子の教えをまとめたものである。,False
# 580,クリスマスイブの夜に枕元に置いておくと、サンタクロースがプレゼントを入れてくれるとされる足に履くファッションアイテムは何?,靴下,ウサギの足,False
# 585,アワと並ぶ日本最古の穀物とされ、寒さに強いことから名がついたとも言われるイネ科の穀物は何?,ヒエ,アワ,False
# 587,扇情的な記事を売り物にする新聞のことを、ある色を使って何ジャーナリズムという?,イエロー・ジャーナリズム,扇情主義,False
# 588,百年戦争の際、勇敢な戦いで劣勢のフランスを鼓舞したことから「オルレアンの少女」と称えられた女性は誰でしょう?,ジャンヌ・ダルク,オルレアンの包囲戦で、勇敢な戦いで,False
# 590,日本の義務教育期間9年間のうち、6年間は小学校に通いますが、残りの3年間に通う学校は何?,中学校,日本の義務教育期間9年間のうち、6年間は小,False
# 593,「Google Chrome」や「Internet Explorer」など、インターネットの情報を閲覧するためのソフトを総称して何というでしょう?,ウェブブラウザ,ブラウザ,False
# 598,本名を富田銀蔵という、明治時代に名を馳せた日本一のスリ一味の大親分は誰でしょう?,仕立屋銀次,富田銀蔵は、明治時代に日本一のスリ一味,False
# 601,『ダイヤルMを廻せ!』『知りすぎていた男』『北北西に進路をとれ』などの数々の映画で知られるアメリカの映画監督は誰でしょう?,アルフレッド・ヒッチコック,ロバート・カミングスは、『ダイヤルMを廻せ,False
# 605,アラビア語で「正しく声を出して読むもの」という意味がある、イスラム教の聖典は何でしょう?,クルアーン,コーラン,False
# 611,郵便局で、使用済みの証として切手やはがきに押す日付印のことを普通何というでしょう?,消印,郵便印,False
# 613,フラーレン、黒鉛、ダイヤモンドといえばいずれもどんな元素から出来ている物質でしょう?,炭素,フラーレン、黒鉛、ダイヤモンドはすべて��,False
# 615,ソテツやイチョウなどに代表される、種子植物の中でも胚珠がむき出しになっているものを何というでしょう?,裸子植物,ソテツやイチョウなどに代表される、種子��,False
# 616,平安時代に「三十六歌仙」を選んだとされる、自身の歌も小倉百人一首に収められている歌人は誰?,藤原公任,小倉百人一首に選ばれている歌人である藤原定,False
# 624,デビュー当時の女子高生の口癖にちなんで芸名がつけられた、『クイズプレゼンバラエティー Qさま!!』で司会を務めているタレントは誰でしょう?,優香,有田哲平,False
# 626,日本の国立大学の中で、唯一、名前にひらがなが使われている大学はどこ?,お茶の水女子大学,横浜国立大学,False
# 635,『ニンテンドウオールスター!大乱闘スマッシュブラザーズ』や『ゼルダの伝説 時のオカリナ』といったソフトが人気を集めた、1996年に発売された任天堂の家庭用ゲーム機は何でしょう?,NINTENDO64,ニンテンドウオールスター!大乱闘スマッ,False
# 639,日本の年号で、「明治」の前は「慶応」ですが、「慶応」の前は何?,元治,慶応の前は慶応です。,False
# 644,「ヤンマの子」が略されたものとされている、トンボの幼虫を意味する言葉は何でしょう?,ヤゴ,ヤンマの子,False
# 645,明治時代の流行語となった言葉で、服装や言動などが非常にあらあらしいことを、「ハイカラ」に対して何という?,バンカラ,ハイカラ,False
# 649,日本で最初に鉄道が開通した時に初代の横浜駅として開業した、現在の横浜駅の隣にある駅は何でしょう?,桜木町駅,横浜駅,False
# 654,宿主と呼ばれる生物に付着して、その生物のから栄養を取って生活する、回虫やサナダムシといった生物のことを何という?,寄生虫,回虫やサナダムシ,False
# 659,旧約聖書の最初に載っている、神の天地創造やアダムとイブについて書かれた書物を何というでしょう?,創世記,旧約聖書の最初に載っている、神の天,False
# 661,日本では大阪府の海遊館や沖縄県の美ら海水族館で見ることができる、魚類の中では最も大きい魚は何でしょう?,ジンベエザメ,日本では大阪府の海遊館や沖縄県,False
# 674,1582年に行われた、羽柴秀吉や柴田勝家らが出席し、織田信長亡き後の後継者や領地の再配分を取り決めた会議のことを何というでしょう?,清洲会議,賤ヶ岳の戦い,False
# 678,「目をぎょろつかせる」という意味がある、登山やスキー、オートバイに乗るときなどに使う目の部分をすっぽりおおう大形の眼鏡を何という?,ゴーグル,ロイド眼鏡,False
# 680,アメリカの巨大IT企業をあらわす言葉で、「FAANG」には含まれるが「GAFA」には含まれていない企業は何でしょう?,Netflix,メタ,False
# 683,マンゴーやマンゴスチンとともに「世界三大美果」にも数えられる、濃厚な甘みがあるバンレイシ科の果物は何?,チェリモヤ,バンレイシ,False
# 684,2002年の第1回ではだいたひかるが優勝した、ピン芸人のナンバーワンを決める大会は何でしょう?,R-1ぐらんぷり,だいたひかるが優勝した第1回R-1ぐらん�,False
# 686,ロバート・ガルブレイスというペンネームで探偵小説を書いていたこともある、『ハリーポッター』シリーズの作者として知られるイギリスの作家は誰でしょう?,J・K・ローリング,J.K.ローリング,False
# 692,競走馬・キタサンブラックが菊花賞や春の天皇賞などで勝利したときに、馬主である北島三郎が歌った、彼の代表曲は何?,まつり,キタサンブラックが勝利した時に、北島三郎は「ま,False
# 694,葉っぱが赤い様子から和名を「ショウジョウボク」という、クリスマス時期に鉢物が出回るトウダイグサ科の植物は何?,ポインセチア,ショウジョウソウ,False
# 695,昭和30年に新村出によって初めて編纂された、日本を代表する国語辞典は何でしょう?,広辞苑,日本国語大辞典,False
# 697,同一区間に新しく作られた鉄道よりも以前からある鉄道のことで、特に新幹線の対義語として使われるのは何でしょう?,在来線,新線,False
# 700,女声の音域で、ソプラノとアルトの中間にあたるものを何というでしょう?,メゾソプラノ,女性の声域で、ソプラノとコントラルトの,False
# 702,日本では「織姫星」とも呼ばれる、こと座のα星は何でしょう?,ベガ,こと座α星は、七夕において織姫星と,False
# 704,大変な食いしん坊であり、半日以上絶食すると餓死してしまう、土を掘って生活している姿が有名なこの生き物は何でしょう?,モグラ,ハンター,False
# 705,総合格闘技の選手が着用する、指が露出したグローブを何というでしょう?,オープンフィンガーグローブ,総合格闘技の選手が着用する、指が�,False
# 706,ナルシストキャラで人気を博している、お笑いコンビ・NON STYLEのツッコミといえば誰でしょう?,井上裕介,石田明,False
# 707,13世紀にクメールを破って、インドシナ半島のチャオプラヤ川流域にタイ族が初めて建国した王朝は何?,スコータイ王朝,タイ,False
# 708,水爆実験によって目覚めた巨大不明生物の姿を描いた、1954年公開の日本の怪獣映画は何でしょう?,ゴジラ,1954年の映画『放射能X』では、放�,False
# 717,西洋では「赤ちゃんを運んでくる」といわれている鳥は何でしょう?,コウノトリ,シュバシコウ,False
# 720,人間の場合は9種類存在する、体内で合成できないために食物から摂取しなければならないアミノ酸のことを何というでしょう?,必須アミノ酸,人間の場合は9種類存在する、体内で合成,False
# 723,警察官の階級で、巡査部長と警部の間にあたるものは何でしょう?,警部補,巡査部長,False
# 727,「40歳過ぎたら自分の顔に責任をもて」という言葉をのこしたとされる、アメリカ第16代大統領は誰?,エイブラハム・リンカーン,ロナルド・レーガン,False
# 728,古代ギリシャの数学者の名前がついた「ヘロンの公式」とは、三角形の三辺の長さから三角形の何を求める公式?,面積,ヘロンの公式」とは、三角形の3辺の長さ,False
# 739,浦島太郎に扮して歌った楽曲『海の声』がヒットし、紅白歌合戦にも出場した俳優は誰でしょう?,桐谷健太,西郷輝彦,False
# 745,メキシコでもっとも面積の広い州にちなむ、イヌの品種は何?,チワワ,ジャイアント・シュナウザー,False
# 750,大分県にある景勝地「青の洞門」の逸話をもとにして書かれた、了海を主人公とする菊池寛の小説は何?,恩讐の彼方に,青の洞門は、菊池寛の小説『����,False
# 753,子ども番組『セサミストリート』に登場する、お腹をくすぐるとすぐに笑い出す、真っ赤な体に大きな鼻が特徴のキャラクターは何?,エルモ,ビッグバード,False
# 767,鳥の子供をヒナといいますが、その中でも特にニワトリのヒナのことを何というでしょう?,ひよこ,ニワトリのヒナのことをヒヨコといいます。,False
# 773,2019年9月1日をもってグループから卒業した、アイドルグループ・乃木坂46の初代キャプテンは誰でしょう?,桜井玲香,秋元真夏,False
# 779,1533年に最後の皇帝アタワルパが処刑されたことで滅亡した、ペルー南部のクスコを中心に発達した国はどこでしょう?,インカ帝国,ペルー,False
# 781,大相撲で、横綱土俵入りが終わり、幕内の取り組みに入るまでの時間のことを何というでしょう?,中入,横綱土俵入りが終わり、幕内,False
# 786,「ポーター」とも呼ばれる、ホテルの玄関から部屋まで客の荷物を運ぶ従業員を何という?,ベルボーイ,ポーターとも呼ばれる、ホテルの玄関から,False
# 787,空気銃にコルクの弾を詰めて、人形・おもちゃなどを的にして撃つ、縁日でおなじみの遊びは何?,射的,空気銃にコルクの弾を詰めて、人形・,False
# 788,小野義眞、岩崎彌之助、井上勝の3人の頭文字をとって命名された、岩手県にある大農場は何でしょう?,小岩井農場,小野義眞、岩崎彌之助、井上勝,False
# 789,ことわざ「敵に塩をおくる」の「敵」とは、誰のこと?,武田信玄,敵に塩を送るの「敵」とは、����,False
# 794,「光や音などの波動が2つの媒質の境界面で屈折するとき、入射角の正弦と屈折角の正弦との比は一定である」という法則を、発見者の名前をとって何という?,スネルの法則,ブリュースター角,False
# 800,中国では福をもたらすとされている動物で、哺乳類の中では唯一羽ばたいて空を飛ぶ、洞窟などに住む生き物は何でしょう?,コウモリ,竜,False
# 803,TVの時代劇でもおなじみだった、徳川光圀の通称として有名な「水戸黄門」の「黄門」が表す役職は何?,中納言,徳川光圀の通称として有名な「水戸黄門」,False
# 806,花粉やハウスダストなど、アレルギーを引き起こす抗原物質のことを何という?,アレルゲン,花粉やハウスダストなど、アレルギーを引き起,False
# 818,食器洗い機やエアコンなどが、システムキッチンや壁面と一体化するように設置されていることを、「作りつけの」という意味の英語で何という?,ビルトイン,システムキッチン,False
# 823,南側はカザフスタンと国境を接するロシア連邦中南部の州で、2013年に推定10トンの隕石が落下し、その衝撃波によって自然災害が起こったことで有名なのはどこでしょう?,チェリャビンスク,ロシア連邦中南部の州で、2013年に推,False
# 827,大豆から豆乳を絞った際に残った搾りかすのことを、特に何というでしょう?,おから,大豆から豆乳を絞った残り�,False
# 829,チェスで、ゲーム開始時に4つの隅に置かれている駒は何でしょう?,ルーク,チェスでは、ゲーム開始時に4つの隅に駒,False
# 837,力士のうち、「関取」と呼ばれるのはどの階級以上の人でしょう?,十両,関取は、大相撲の番付の階級の総,False
# 844,野口雨情作詞の『兎のダンス』、北原白秋作詞の『あわて床屋』、三木露風作詞の『赤とんぼ』などを作曲した日本の作曲家は誰でしょう?,山田耕筰,野口雨情作詞の『兎のダンス』、北原,False
# 846,ドイツ人のルドルフ・ダスラーが創業した、あるネコ科の動物の名前が付いたスポーツウェアメーカーは何でしょう?,プーマ,アディダス,False
# 850,イタリア語の「ひも」という意味の言葉に由来する、日本でもナポリタンなどの材料としておなじみの細長いパスタは何?,スパゲッティ,カペッリーニ,False
# 854,日本にある海に面していない都道府県のうち、最も西にあるのはどこでしょう?,奈良県,香美市,False
# 857,「仲良きことは美しき哉」という名言でも知られる白樺派の作家は誰?,武者小路実篤,有島武郎は、『仲良きことは美しき哉』と,False
# 859,劇団四季の『マンマ・ミーア!』は、スウェーデンの何というポップグループのヒット曲で構成されたミュージカル?,ABBA,マンマ・ミーア!,False
# 860,双六で進むマスを決めるのはサイコロですが、人生ゲームで進むマスを決めるのは何でしょう?,ルーレット,人生ゲームでは、サイコロを振る代わりにルー,False
# 864,宮城道雄の曲『春の海』のモチーフになったといわれる、広島県福山市南部の海岸地帯は何?,鞆の浦,福山市,False
# 865,『晩鐘』『種蒔く人』『落穂拾い』などの作品で知られるフランスの画家は誰でしょう?,ジャン=フランソワ・ミレー,ジャン＝フランソワ・ミレー,False
# 866,妻が映画監督・伊丹十三の妹であるという芥川賞作家は誰?,大江健三郎,芥川賞作家の山本周五郎は、妻が宮本,False
# 873,沖縄県では、かつて鍋を洗う時に使ったことから「ナーベラー」とも呼ばれる食べ物は何でしょう?,ヘチマ,ンブシー,False
# 877,ワイナ・カパックやアタワルパなどの王がいた、15〜16世紀の南米に築かれた国は何でしょう?,インカ帝国,エクアドル,False
# 889,大きく「反射式」と「屈折式」の2種類に分けられる、夜空の天体を観察する際に使われる道具は何でしょう?,望遠鏡,天体観測は、反射式と屈折式,False
# 890,140と195、48と75などのように、1とそれ自身を除いた約数の和が互いに他方と等しくなるような1組の自然数を何という?,婚約数,140と195、48と75などのように、1とそ,False
# 893,日本では「黄色人種」と呼ばれる、五大人種のひとつは何でしょう?,モンゴロイド,日本では「黄色人種」と呼ばれる、五大人,False
# 897,女優としても映画『君と100回目の恋』に主演した、『don’t cry anymore』 『ヒカリへ』などの曲で知られるシンガーソングライターは誰でしょう?,miwa,桐谷美玲さん,False
# 899,優勝カップを寄贈したアメリカ人テニスプレイヤーの名前がついた、テニスの男子国別対抗戦の通称は何?,デビスカップ,ホップマンカップ,False
# 905,2019年の日本プロ野球で、ベイスターズのスペンサー・パットンがジャイアンツ戦で降板を命じられた後、殴りつけて拳を負傷する原因となった家電製品は何でしょう?,冷蔵庫,スペンサー・パットンは、2019年の巨人戦,False
# 908,ベンチに横たわって、胸の上でバーベルの上げ下げを行い大胸筋などを鍛えるトレーニングを何という?,ベンチプレス,ベンチに横たわった状態で、肩幅,False
# 911,「大関の脇をつとめる」ということから名が付いたとされる、大相撲の番付で大関の1つ下に当たる位は何でしょう?,関脇,小結,False
# 919,野球で、バントの構えからヒッティングに移ることを何というでしょう?,バスター,バントの構えからヒッティングに移ることをバ,False
# 920,ポーランドの農村を舞台に、人形に恋する青年・フランツと、彼に惹かれる娘・スワニルダを描いたバレエ作品は何?,コッペリア,ポーランドの農村を舞台に、人形に恋する青年,False
# 924,英語で「原文」や「教科書」という意味があるほか、コンピュータ用語としては文字コードだけで構成されたデータを指して使われる言葉は何でしょう?,テキスト,原文、教科書,False
# 925,音楽CDやDVDのデータをデジタルデータに変換してパソコンに取り込むことを英語で何という?,リッピング,音楽CDやDVDのデータをデジタルデータに変換,False
# 926,フランスでは「コンフィチュール」と呼ばれる、ロシアンティーの中に溶かしたり、パンに塗ったりする甘い食べ物は何でしょう?,ジャム,パート・ド・フリュイ,False
# 927,魚肉や酢の物などに用いる、酢としょう油に砂糖かみりんを合わせた甘みのある調味料を何という?,三杯酢,甘酢,False
# 944,「ちょっと何言ってるか分からない」というセリフで知られる、お笑いコンビ・サンドウィッチマンのメンバーは誰?,富澤たけし,サンドウィッチマンは、伊達みきおと富澤たけ,False
# 945,シュークリームの「シュー」とはフランス語でこの野菜のことをさしている、コールスローサラダの材料として使われる野菜といえば何でしょう?,キャベツ,シュークリームの「シュー」はフランス語でキャベ,False
# 951,日本語では「工場制手工業」という、機械制大工業が出現する以前に行われていた最初の資本主義的生産形態のことを英語で何というでしょう?,マニュファクチュア,工場制手工業,False
# 954,将棋の一種「はさみ将棋」で使われる、唯一の駒は何でしょう?,歩兵,盲犬は、将棋の駒の一つ。,False
# 964,旅客機の座席で、ファーストクラスとエコノミークラスの中間にあたるものを一般に何クラスというでしょう?,ビジネスクラス,エコノミークラス,False
# 966,2020年シーズン、読売ジャイアンツの丸佳浩が試合での登場時に主に流していたのは、何という歌手の楽曲でしょう?,LiSA,2020年シーズン、読売ジャイアンツの,False
# 967,2人で行う花札の遊び方で、「五光」や「猪鹿蝶」といった役があるのは何?,こいこい,花札の遊び方で、2人で行うものとしては,False
# 978,掛け算で使う「×」の記号のもとになったものは何?,十字架,掛け算の「掛ける」を意味する英語の,False
# 979,細長く切ったイカの刺し身を、醤油やつけ汁につけて食べる料理のことを、ある麺類にたとえて何という?,イカそうめん,イカの刺し身を、醤油やつけ汁に,False
